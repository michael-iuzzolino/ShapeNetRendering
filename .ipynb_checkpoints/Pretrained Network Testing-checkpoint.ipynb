# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import json
import glob
import cv2
import imageio
import numpy as np

import torch
import torch.nn as nn
import torchvision
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
import modules.ShapeNet
import matplotlib.pyplot as plt
import modules.utils
import modules.pytorch_utils
import modules.BackgroundImages
from collections import Counter
from IPython.display import Image, display

# %% [markdown]
# # Transformations

# %%
imagenet_xforms = modules.pytorch_utils.load_imagenet_transformations()
transformations = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    imagenet_xforms['normalize']
])

# %% [markdown]
# # ShapnetHandler

# %%
shapenet_root = "/hdd/mliuzzolino/ShapeNet/data/ShapeNetCore.v2"
shapenet_handler = modules.ShapeNet.Handler(shapenet_root)

# %%
imagenet_labels_root = "info/imagenet_class_index.json"
imagenet_idx2label = modules.utils.load_imagenet_labels(imagenet_labels_root)
shapenet_handler.align_with_shapenet(imagenet_idx2label)

# %% [markdown]
# # Device

# %%
# !nvidia-smi
# Out:
# Fri Mar 13 00:46:33 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 440.33.01    CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN Xp            Off  | 00000000:05:00.0 Off |                  N/A |
# | 40%   64C    P2    64W / 250W |   1217MiB / 12194MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  TITAN Xp            Off  | 00000000:09:00.0 Off |                  N/A |
# | 23%   35C    P8     9W / 250W |     10MiB / 12196MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     28454      C   ...e/michael/anaconda3/envs/ml2/bin/python  1207MiB |
# +-----------------------------------------------------------------------------+

# %%
GPU_ON = True
GPU_num = 0
RANDOM_SEED = 42
DEVICE = torch.device(f"cuda:{GPU_num}" if torch.cuda.is_available() and GPU_ON else 'cpu')

# Utils.set_seed(RANDOM_SEED)
print(f"Device: {DEVICE}")
print(f"Random seed: {RANDOM_SEED}")
# Out:
# Device: cuda:0
# Random seed: 42

# %% [markdown]
# # Pretrained Model

# %%
# Source: https://pytorch.org/docs/stable/torchvision/models.html
resnet18 = models.resnet18(pretrained=True).to(DEVICE)

# %% [markdown]
# ## Background Images

# %%
background_params = {
    "root"               : '/hdd/mliuzzolino/Places2/places365_standard/train',
    "labels_root"        : '/hdd/mliuzzolino/Places2/predicted_labels',
    "eval_model"         : 'resnet18'
}
background = modules.BackgroundImages.BackgroundHandler(**background_params)
# Out:
# Building image paths...
# Loading labeled path lookup...

# %%
background.list_possible_filter_names()
# Out:
# Counter({'table_lamp': 2667,
#          'oxygen_mask': 3425,
#          'safe': 3650,
#          'boston_bull': 558,
#          'barrel': 1363,
#          'seashore': 8644,
#          'stole': 1497,
#          'greenhouse': 10290,
#          'cannon': 1384,
#          'soccer_ball': 5988,
#          'scoreboard': 3796,
#          'american_lobster': 1465,
#          'dining_table': 8220,
#          'pedestal': 5140,
#          'refrigerator': 5671,
#          'cougar': 524,
#          'paddle': 4627,
#          'sarong': 1539,
#          'military_uniform': 3447,
#          'toyshop': 17229,
#          'bannister': 10184,
#          'water_tower': 4156,
#          'bubble': 1914,
#          'coral_reef': 2547,
#          'car_wheel': 2008,
#          'coho': 2056,
#          'park_bench': 6580,
#          'mountain_tent': 4086,
#          'flagpole': 3073,
#          'switch': 1572,
#          'palace': 15710,
#          'throne': 5012,
#          'typewriter_keyboard': 675,
#          'abacus': 1812,
#          'clumber': 152,
#          'electric_fan': 2623,
#          'pencil_box': 860,
#          'freight_car': 2066,
#          'speedboat': 3119,
#          'mobile_home': 16666,
#          'bulletproof_vest': 269,
#          'quilt': 4367,
#          'power_drill': 1367,
#          'dome': 5340,
#          'cellular_telephone': 1888,
#          'mitten': 908,
#          'china_cabinet': 3747,
#          'umbrella': 3176,
#          'fountain': 8367,
#          'monastery': 9126,
#          "carpenter's_kit": 2447,
#          'snorkel': 3027,
#          'cleaver': 1077,
#          'warplane': 9612,
#          'maze': 5845,
#          'electric_guitar': 3320,
#          'zebra': 742,
#          'nail': 2498,
#          'german_shepherd': 456,
#          'afghan_hound': 660,
#          'wardrobe': 7774,
#          'ram': 1437,
#          'ostrich': 1805,
#          'promontory': 10458,
#          'croquet_ball': 4524,
#          'ballplayer': 8851,
#          'spider_monkey': 491,
#          'grey_fox': 265,
#          'envelope': 1021,
#          'albatross': 1736,
#          'dock': 4219,
#          'megalith': 5462,
#          'carousel': 9462,
#          'studio_couch': 7775,
#          'lakeside': 16721,
#          'doormat': 2831,
#          'loudspeaker': 1178,
#          'fire_engine': 2832,
#          'stage': 15919,
#          'drum': 3816,
#          'sorrel': 5120,
#          'parking_meter': 1401,
#          'trimaran': 1174,
#          'mortar': 1563,
#          'screwdriver': 1126,
#          'geyser': 2266,
#          'bittern': 818,
#          'hay': 9209,
#          'stingray': 1613,
#          'space_heater': 2414,
#          'pool_table': 3104,
#          'medicine_chest': 5810,
#          'laptop': 2256,
#          'file': 3100,
#          'boathouse': 10838,
#          'patio': 9492,
#          'boxer': 243,
#          'valley': 14333,
#          'joystick': 1463,
#          'vault': 10847,
#          'drilling_platform': 4148,
#          'shoe_shop': 10146,
#          'streetcar': 4762,
#          'wing': 3276,
#          'shoji': 3030,
#          'jeep': 1855,
#          'bighorn': 1156,
#          'grasshopper': 214,
#          'racer': 4884,
#          'barbershop': 7564,
#          'microwave': 9273,
#          'church': 8719,
#          'castle': 11291,
#          'warthog': 714,
#          'bluetick': 493,
#          'daisy': 2153,
#          'steel_arch_bridge': 2908,
#          'grocery_store': 9692,
#          'syringe': 2355,
#          'rotisserie': 4517,
#          'jackfruit': 945,
#          'library': 6889,
#          'chime': 2266,
#          'crate': 2796,
#          'mailbox': 2799,
#          'maypole': 1806,
#          'catamaran': 1304,
#          'sliding_door': 7783,
#          'prison': 9137,
#          'pelican': 761,
#          'american_black_bear': 1254,
#          'mountain_bike': 2765,
#          'racket': 3318,
#          'stone_wall': 6292,
#          'rocking_chair': 3766,
#          'restaurant': 16816,
#          'coil': 4903,
#          'beacon': 7180,
#          'honeycomb': 1354,
#          'grey_whale': 3046,
#          'obelisk': 1957,
#          'great_white_shark': 1216,
#          'viaduct': 8077,
#          'pekinese': 69,
#          'cliff': 5989,
#          'monitor': 2560,
#          'rapeseed': 4318,
#          'seat_belt': 6149,
#          'moped': 1635,
#          'miniskirt': 1736,
#          'african_elephant': 705,
#          'thresher': 1446,
#          'hammer': 1550,
#          'chain': 1004,
#          'pot': 7441,
#          'passenger_car': 7206,
#          'hot_pot': 1545,
#          'ping-pong_ball': 2752,
#          'swing': 4614,
#          'washbasin': 3996,
#          'paper_towel': 2437,
#          'brittany_spaniel': 151,
#          'yurt': 2608,
#          'radio': 2069,
#          'bucket': 3004,
#          'crash_helmet': 1974,
#          'artichoke': 338,
#          'harmonica': 2045,
#          'brassiere': 762,
#          'breakwater': 3536,
#          'lab_coat': 5252,
#          'ice_lolly': 1241,
#          'tile_roof': 4261,
#          'bell_cote': 13535,
#          'convertible': 2103,
#          'tobacco_shop': 13860,
#          'altar': 4060,
#          'volcano': 14685,
#          'window_screen': 3429,
#          'american_alligator': 2823,
#          'beach_wagon': 2856,
#          'tub': 4029,
#          'cheeseburger': 209,
#          'sandbar': 8977,
#          'acoustic_guitar': 976,
#          'kelpie': 380,
#          'lotion': 443,
#          'bagel': 267,
#          'home_theater': 9975,
#          'bullfrog': 528,
#          'maraca': 3381,
#          'crane': 4361,
#          'rugby_ball': 3181,
#          'window_shade': 5555,
#          'carton': 928,
#          'vacuum': 2499,
#          'airliner': 5270,
#          'dam': 7520,
#          'jersey': 1190,
#          'conch': 2226,
#          'volleyball': 4385,
#          'chainlink_fence': 3775,
#          'accordion': 1710,
#          'cinema': 9413,
#          'trilobite': 1768,
#          'barrow': 4141,
#          'ibex': 2456,
#          'perfume': 1996,
#          'great_grey_owl': 581,
#          'mosque': 6494,
#          'quill': 2224,
#          'bookcase': 5452,
#          'gas_pump': 3727,
#          'balance_beam': 2636,
#          'leatherback_turtle': 3834,
#          'rock_crab': 1067,
#          'panpipe': 1018,
#          'bearskin': 1839,
#          'beer_glass': 1332,
#          'purse': 752,
#          'academic_gown': 1287,
#          'rifle': 953,
#          'pencil_sharpener': 1847,
#          'torch': 1859,
#          'birdhouse': 10726,
#          'unicycle': 2553,
#          'arabian_camel': 3601,
#          'four-poster': 6500,
#          'mortarboard': 1367,
#          'butcher_shop': 6770,
#          'trailer_truck': 2873,
#          'lorikeet': 535,
#          'iron': 1264,
#          'tractor': 1244,
#          'plate': 2779,
#          'jinrikisha': 1965,
#          'tusker': 608,
#          'ice_cream': 848,
#          'red-breasted_merganser': 368,
#          'dogsled': 2327,
#          'standard_schnauzer': 140,
#          'dingo': 341,
#          'broccoli': 4236,
#          'cricket': 237,
#          'microphone': 3448,
#          'organ': 2134,
#          'vulture': 940,
#          'fiddler_crab': 801,
#          'fire_screen': 2417,
#          'golf_ball': 3834,
#          'airship': 1248,
#          'basketball': 7312,
#          'tray': 3618,
#          'ladle': 1016,
#          'apiary': 1965,
#          'hippopotamus': 1555,
#          'cash_machine': 3183,
#          'cockroach': 589,
#          'pickup': 1608,
#          'sunglasses': 646,
#          'thatch': 4266,
#          'plow': 3742,
#          'paintbrush': 1742,
#          'dial_telephone': 790,
#          'suspension_bridge': 5362,
#          'soap_dispenser': 1687,
#          'swab': 1589,
#          'television': 2360,
#          'agama': 651,
#          'combination_lock': 858,
#          'teapot': 499,
#          'stethoscope': 1819,
#          'parallel_bars': 2899,
#          'minibus': 2818,
#          'wok': 2475,
#          'hen-of-the-woods': 1072,
#          'street_sign': 3763,
#          'book_jacket': 2263,
#          'tank': 1004,
#          "potter's_wheel": 2241,
#          'washer': 4991,
#          'spindle': 634,
#          'sewing_machine': 3150,
#          'coral_fungus': 618,
#          'theater_curtain': 3170,
#          'projectile': 2521,
#          'triumphal_arch': 4161,
#          'puck': 7200,
#          'bow': 3093,
#          'folding_chair': 3321,
#          'sea_snake': 546,
#          'desk': 9168,
#          'binder': 1995,
#          'toilet_tissue': 1245,
#          'mosquito_net': 1009,
#          'dough': 768,
#          'amphibian': 1667,
#          'sports_car': 4268,
#          'handkerchief': 1019,
#          'burrito': 681,
#          'fur_coat': 1849,
#          'bikini': 855,
#          'football_helmet': 4989,
#          'disk_brake': 3845,
#          'spider_web': 1312,
#          'measuring_cup': 265,
#          'lawn_mower': 2316,
#          'barn': 13931,
#          'stove': 4409,
#          'car_mirror': 2540,
#          'gordon_setter': 309,
#          'sax': 1465,
#          'wool': 1723,
#          'ski': 5626,
#          'pug': 577,
#          'pirate': 1863,
#          'revolver': 504,
#          'lampshade': 1741,
#          'grand_piano': 3235,
#          'mask': 1774,
#          'kimono': 1878,
#          'prayer_rug': 1031,
#          'worm_fence': 12359,
#          'cello': 1154,
#          'punching_bag': 2347,
#          'picket_fence': 4732,
#          'alp': 12061,
#          'packet': 2898,
#          'anemone_fish': 255,
#          'rhinoceros_beetle': 572,
#          'turnstile': 5667,
#          'gar': 1610,
#          'submarine': 2613,
#          'digital_clock': 1392,
#          'dumbbell': 2888,
#          'necklace': 893,
#          'bathtub': 2551,
#          'toaster': 2332,
#          'upright': 1068,
#          'hyena': 1089,
#          'fountain_pen': 547,
#          'canoe': 4032,
#          'wallet': 1059,
#          'bow_tie': 1601,
#          'spiny_lobster': 816,
#          'lifeboat': 744,
#          'dishwasher': 5147,
#          'modem': 518,
#          'king_crab': 292,
#          'scabbard': 824,
#          'minivan': 1941,
#          'pitcher': 457,
#          'tench': 776,
#          'school_bus': 1272,
#          'broom': 1548,
#          'pill_bottle': 752,
#          'hair_slide': 1372,
#          'hamper': 2855,
#          'african_hunting_dog': 587,
#          'ice_bear': 1823,
#          'chain_mail': 971,
#          'bookshop': 4865,
#          'espresso': 385,
#          'trolleybus': 2625,
#          'steel_drum': 1395,
#          'cradle': 2093,
#          'jean': 1112,
#          'hammerhead': 600,
#          'bullet_train': 3869,
#          'pole': 4952,
#          'hourglass': 1758,
#          'ant': 1624,
#          'vending_machine': 3690,
#          'gondola': 2461,
#          'bottlecap': 736,
#          'limousine': 1899,
#          'notebook': 1629,
#          'hatchet': 1203,
#          'aircraft_carrier': 5321,
#          'printer': 2235,
#          'barber_chair': 6486,
#          'abaya': 1062,
#          'hummingbird': 549,
#          'planetarium': 3544,
#          'custard_apple': 534,
#          'black_stork': 410,
#          'butternut_squash': 182,
#          'timber_wolf': 165,
#          'cock': 1230,
#          'african_crocodile': 2182,
#          'king_penguin': 885,
#          'sea_lion': 1921,
#          'vine_snake': 266,
#          'bobsled': 1779,
#          'miniature_pinscher': 500,
#          'barbell': 2098,
#          'parachute': 2217,
#          'golfcart': 2232,
#          'projector': 2684,
#          'padlock': 1177,
#          'sloth_bear': 642,
#          'boa_constrictor': 593,
#          'paddlewheel': 1138,
#          'otter': 1066,
#          'shield': 2054,
#          'tailed_frog': 390,
#          'schooner': 899,
#          'crossword_puzzle': 1287,
#          'cowboy_boot': 1186,
#          'lighter': 1284,
#          'lumbermill': 3488,
#          'bakery': 5818,
#          'italian_greyhound': 984,
#          'zucchini': 750,
#          'robin': 277,
#          'killer_whale': 1947,
#          'loggerhead': 912,
#          'wine_bottle': 1217,
#          'radiator': 1921,
#          'goblet': 559,
#          'terrapin': 875,
#          'brain_coral': 686,
#          'cliff_dwelling': 4249,
#          'comic_book': 2678,
#          'slot': 4744,
#          'oxcart': 1034,
#          'whiptail': 578,
#          'pinwheel': 914,
#          'hartebeest': 1337,
#          'echidna': 1006,
#          'ashcan': 2751,
#          'pier': 4464,
#          'colobus': 656,
#          'apron': 770,
#          'plastic_bag': 2056,
#          'waffle_iron': 1773,
#          'shower_curtain': 2319,
#          'spotlight': 1933,
#          'entertainment_center': 2049,
#          'llama': 1291,
#          'magpie': 344,
#          'hand_blower': 2149,
#          'saint_bernard': 130,
#          'hog': 1274,
#          'snowplow': 2465,
#          'australian_terrier': 83,
#          'lipstick': 483,
#          'bolete': 738,
#          'jigsaw_puzzle': 2820,
#          'jellyfish': 1860,
#          'brass': 2073,
#          'confectionery': 7772,
#          'moving_van': 1417,
#          'desktop_computer': 1611,
#          'sturgeon': 988,
#          'stinkhorn': 664,
#          'gazelle': 951,
#          'band_aid': 911,
#          'toilet_seat': 2985,
#          'spoonbill': 327,
#          'tripod': 1100,
#          'recreational_vehicle': 1437,
#          'vase': 1490,
#          'sea_urchin': 883,
#          'indian_cobra': 693,
#          'saltshaker': 503,
#          'plunger': 2063,
#          'pajama': 2083,
#          'water_snake': 1714,
#          'model_t': 811,
#          'knee_pad': 1722,
#          'badger': 588,
#          'banana': 522,
#          'ladybug': 279,
#          'hip': 866,
#          'stupa': 3909,
#          'safety_pin': 1985,
#          'macaque': 213,
#          'dungeness_crab': 887,
#          'liner': 2152,
#          'letter_opener': 196,
#          'shopping_basket': 2370,
#          'shopping_cart': 2900,
#          'norwich_terrier': 80,
#          'rubber_eraser': 454,
#          'dutch_oven': 1112,
#          'stretcher': 6404,
#          'assault_rifle': 1041,
#          'nipple': 843,
#          'crib': 3303,
#          'solar_dish': 4350,
#          'sea_cucumber': 1031,
#          'wreck': 4098,
#          'shower_cap': 1134,
#          'triceratops': 2676,
#          'electric_locomotive': 2041,
#          'beaker': 994,
#          'forklift': 2756,
#          'hard_disc': 1340,
#          'jay': 287,
#          'saluki': 598,
#          'suit': 2522,
#          'candle': 2714,
#          'hair_spray': 1439,
#          'bolo_tie': 390,
#          'capuchin': 309,
#          'balloon': 744,
#          'swimming_trunks': 1881,
#          'horizontal_bar': 1423,
#          'bee': 1260,
#          'shovel': 4234,
#          'knot': 1183,
#          'harp': 687,
#          'french_bulldog': 224,
#          'bassinet': 1053,
#          'container_ship': 2506,
#          'hermit_crab': 759,
#          'cd_player': 1029,
#          'schipperke': 384,
#          'pizza': 2507,
#          'muzzle': 2597,
#          'leaf_beetle': 60,
#          'sundial': 4580,
#          'meerkat': 260,
#          'bath_towel': 618,
#          'sweatshirt': 465,
#          'photocopier': 2526,
#          'grille': 2099,
#          'tricycle': 2368,
#          'ambulance': 1208,
#          'radio_telescope': 1925,
#          'menu': 588,
#          'orangutan': 508,
#          'blenheim_spaniel': 76,
#          'tow_truck': 1728,
#          'impala': 724,
#          'mongoose': 514,
#          'scuba_diver': 1108,
#          'wolf_spider': 316,
#          'indian_elephant': 637,
#          'harvester': 2325,
#          'potpie': 400,
#          'american_egret': 1145,
#          'cassette': 686,
#          'chain_saw': 3698,
#          'odometer': 533,
#          'bathing_cap': 2069,
#          'sea_slug': 601,
#          'nematode': 1393,
#          'chocolate_sauce': 782,
#          'thimble': 926,
#          'bison': 1271,
#          'green_lizard': 286,
#          'cocktail_shaker': 228,
#          'dung_beetle': 608,
#          'baseball': 1901,
#          'garbage_truck': 1819,
#          'lacewing': 479,
#          'espresso_maker': 1937,
#          'starfish': 983,
#          'marmot': 658,
#          'coucal': 414,
#          'sleeping_bag': 1554,
#          'water_ouzel': 915,
#          'gown': 1523,
#          'tennis_ball': 2470,
#          'clog': 1039,
#          'golden_retriever': 269,
#          'marimba': 3231,
#          'crutch': 2310,
#          'pop_bottle': 606,
#          'neck_brace': 1447,
#          'ox': 3343,
#          'cassette_player': 228,
#          'goldfish': 1187,
#          'trifle': 262,
#          'coyote': 507,
#          'bell_pepper': 476,
#          'plane': 807,
#          'traffic_light': 3504,
#          'puffer': 306,
#          'beaver': 760,
#          'chihuahua': 970,
#          'guillotine': 2195,
#          'head_cabbage': 764,
#          'maillot': 1380,
#          'binoculars': 1200,
#          'screen': 1919,
#          'frying_pan': 751,
#          'carbonara': 141,
#          'plate_rack': 1183,
#          'ocarina': 1034,
#          'mud_turtle': 381,
#          'cloak': 847,
#          'diamondback': 503,
#          'steam_locomotive': 2086,
#          'buckeye': 1151,
#          'loupe': 302,
#          'tick': 866,
#          'space_shuttle': 2034,
#          'banjo': 1067,
#          'platypus': 1058,
#          'welsh_springer_spaniel': 103,
#          'groom': 2698,
#          'violin': 880,
#          'cab': 4205,
#          'weasel': 574,
#          'porcupine': 504,
#          'eel': 1495,
#          'stopwatch': 146,
#          'bicycle-built-for-two': 1100,
#          'english_springer': 266,
#          'chesapeake_bay_retriever': 709,
#          'airedale': 245,
#          'mink': 439,
#          'leonberg': 231,
#          'european_fire_salamander': 213,
#          'rottweiler': 294,
#          'ear': 2388,
#          'police_van': 318,
#          'white_stork': 343,
#          'rule': 1045,
#          'lycaenid': 150,
#          'ptarmigan': 1906,
#          'african_chameleon': 512,
#          'irish_terrier': 117,
#          'damselfly': 319,
#          'coffeepot': 703,
#          'dugong': 357,
#          'pay-phone': 4390,
#          'chiton': 716,
#          'kerry_blue_terrier': 622,
#          'reel': 2042,
#          'flatworm': 454,
#          'wall_clock': 1362,
#          'bustard': 825,
#          'screw': 1092,
#          'corn': 1219,
#          'sandal': 544,
#          'dishrag': 484,
#          'howler_monkey': 772,
#          'petri_dish': 314,
#          'malinois': 378,
#          'flamingo': 290,
#          'entlebucher': 188,
#          'black_widow': 297,
#          'gasmask': 887,
#          'axolotl': 373,
#          'electric_ray': 736,
#          'mexican_hairless': 540,
#          'beer_bottle': 1258,
#          'pillow': 871,
#          'common_newt': 453,
#          'macaw': 1134,
#          'chiffonier': 604,
#          'armadillo': 870,
#          'banded_gecko': 460,
#          'consomme': 169,
#          'chest': 1910,
#          'horse_cart': 1847,
#          'water_buffalo': 1146,
#          'alligator_lizard': 190,
#          'trombone': 885,
#          'lesser_panda': 211,
#          'oystercatcher': 485,
#          'english_setter': 314,
#          'french_loaf': 488,
#          'crayfish': 1157,
#          'sea_anemone': 355,
#          'cuirass': 549,
#          'common_iguana': 1055,
#          "yellow_lady's_slipper": 216,
#          'half_track': 1001,
#          'feather_boa': 1097,
#          'analog_clock': 1050,
#          'velvet': 791,
#          'bloodhound': 378,
#          'sulphur_butterfly': 336,
#          'marmoset': 323,
#          'tree_frog': 203,
#          'fig': 562,
#          'mousetrap': 2866,
#          'running_shoe': 622,
#          'french_horn': 507,
#          'eskimo_dog': 185,
#          'peacock': 981,
#          'eggnog': 433,
#          'yorkshire_terrier': 122,
#          'flute': 730,
#          'manhole_cover': 654,
#          'remote_control': 881,
#          'tiger': 179,
#          'wig': 1751,
#          'oscilloscope': 1893,
#          'milk_can': 360,
#          'angora': 186,
#          'backpack': 562,
#          'motor_scooter': 1928,
#          'barracouta': 410,
#          'rain_barrel': 1504,
#          'toucan': 267,
#          'strainer': 1131,
#          'trench_coat': 463,
#          'lynx': 380,
#          'scottish_deerhound': 303,
#          'hook': 824,
#          'komondor': 212,
#          'bulbul': 121,
#          'windsor_tie': 571,
#          'scale': 2019,
#          'curly-coated_retriever': 463,
#          'go-kart': 955,
#          'sombrero': 1474,
#          'tabby': 371,
#          'earthstar': 393,
#          'rhodesian_ridgeback': 192,
#          'dowitcher': 341,
#          'labrador_retriever': 471,
#          'polaroid_camera': 891,
#          'horned_viper': 757,
#          'irish_water_spaniel': 293,
#          'spatula': 1007,
#          'overskirt': 279,
#          'borzoi': 128,
#          'mashed_potato': 176,
#          'oboe': 1101,
#          'sunglass': 889,
#          'hoopskirt': 768,
#          'acorn': 698,
#          'arctic_fox': 616,
#          'leafhopper': 422,
#          'weimaraner': 375,
#          'strawberry': 296,
#          'vestment': 2133,
#          'pembroke': 113,
#          'pretzel': 388,
#          'breastplate': 888,
#          'brown_bear': 605,
#          'totem_pole': 611,
#          'christmas_stocking': 748,
#          'drumstick': 1277,
#          'scotch_terrier': 440,
#          'bassoon': 1885,
#          'pomegranate': 389,
#          'frilled_lizard': 965,
#          'wire-haired_fox_terrier': 92,
#          'water_bottle': 954,
#          'redshank': 155,
#          'european_gallinule': 313,
#          'soup_bowl': 327,
#          'gyromitra': 326,
#          'guenon': 181,
#          'cabbage_butterfly': 440,
#          'american_coot': 436,
#          'tape_player': 1333,
#          'missile': 945,
#          'maltese_dog': 65,
#          'cowboy_hat': 1124,
#          'ibizan_hound': 422,
#          'wallaby': 684,
#          'red_fox': 88,
#          'sulphur-crested_cockatoo': 268,
#          'quail': 316,
#          'mushroom': 573,
#          'piggy_bank': 477,
#          'poncho': 770,
#          'great_dane': 698,
#          'sunscreen': 625,
#          'appenzeller': 187,
#          'ruddy_turnstone': 274,
#          'lion': 583,
#          'diaper': 699,
#          'pickelhaube': 523,
#          'can_opener': 1091,
#          'basenji': 246,
#          'bouvier_des_flandres': 253,
#          'oil_filter': 1256,
#          'house_finch': 203,
#          'teddy': 1212,
#          'hare': 496,
#          'dhole': 165,
#          'goose': 1076,
#          'bedlington_terrier': 179,
#          'cardigan': 775,
#          'gila_monster': 501,
#          'cauliflower': 392,
#          'lionfish': 410,
#          'caldron': 1176,
#          'granny_smith': 367,
#          'slug': 517,
#          'acorn_squash': 361,
#          'black-footed_ferret': 312,
#          'black_swan': 687,
#          'skunk': 550,
#          'doberman': 345,
#          'miniature_schnauzer': 74,
#          'red_wine': 537,
#          'hotdog': 306,
#          'ground_beetle': 66,
#          'hamster': 343,
#          'wood_rabbit': 340,
#          'matchstick': 1085,
#          'little_blue_heron': 630,
#          'scorpion': 612,
#          'flat-coated_retriever': 399,
#          'bee_eater': 132,
#          'madagascar_cat': 336,
#          'pineapple': 625,
#          'corkscrew': 479,
#          'irish_wolfhound': 180,
#          'baboon': 439,
#          'harvestman': 238,
#          'basset': 296,
#          'mouse': 895,
#          'fireboat': 1458,
#          'barometer': 154,
#          'computer_keyboard': 601,
#          'mailbag': 633,
#          'chambered_nautilus': 334,
#          'giant_panda': 131,
#          'whippet': 833,
#          'ipod': 724,
#          'prairie_chicken': 491,
#          'meat_loaf': 554,
#          'goldfinch': 114,
#          'shetland_sheepdog': 101,
#          'shih-tzu': 114,
#          'langur': 193,
#          'hen': 692,
#          'buckle': 1163,
#          'ballpoint': 304,
#          'african_grey': 497,
#          'chimpanzee': 587,
#          'bull_mastiff': 168,
#          'leopard': 272,
#          'tarantula': 881,
#          'staffordshire_bullterrier': 588,
#          'coffee_mug': 429,
#          'centipede': 522,
#          'tiger_shark': 307,
#          'lens_cap': 165,
#          'snow_leopard': 288,
#          'american_staffordshire_terrier': 333,
#          'drake': 834,
#          'face_powder': 339,
#          'gong': 605,
#          'patas': 85,
#          'barn_spider': 159,
#          'cicada': 436,
#          'mixing_bowl': 339,
#          'pick': 802,
#          'ruffed_grouse': 315,
#          'loafer': 754,
#          'koala': 354,
#          'weevil': 138,
#          'box_turtle': 178,
#          'border_collie': 285,
#          'wooden_spoon': 625,
#          'bald_eagle': 462,
#          'white_wolf': 112,
#          'garter_snake': 132,
#          'red_wolf': 61,
#          'snail': 276,
#          'siberian_husky': 127,
#          'cheetah': 853,
#          'cairn': 100,
#          'gorilla': 297,
#          'agaric': 78,
#          'briard': 180,
#          'walking_stick': 1116,
#          'chow': 38,
#          'whistle': 516,
#          'standard_poodle': 456,
#          'ski_mask': 1055,
#          'wombat': 769,
#          'brambling': 115,
#          'groenendael': 192,
#          'cucumber': 665,
#          'gibbon': 78,
#          'three-toed_sloth': 609,
#          'norwegian_elkhound': 103,
#          'kite': 445,
#          'bonnet': 525,
#          'giant_schnauzer': 255,
#          'web_site': 703,
#          'black_grouse': 660,
#          'fox_squirrel': 168,
#          'cup': 369,
#          'black_and_gold_garden_spider': 29,
#          'dalmatian': 390,
#          'hornbill': 482,
#          'guacamole': 158,
#          'sussex_spaniel': 194,
#          'long-horned_beetle': 157,
#          'samoyed': 88,
#          'squirrel_monkey': 145,
#          'toy_poodle': 280,
#          'red-backed_sandpiper': 200,
#          'snowmobile': 1307,
#          'admiral': 104,
#          'space_bar': 177,
#          'greater_swiss_mountain_dog': 256,
#          'night_snake': 209,
#          'siamang': 245,
#          'magnetic_compass': 411,
#          'tiger_beetle': 64,
#          'titi': 110,
#          'tiger_cat': 246,
#          'great_pyrenees': 106,
#          'bib': 332,
#          'lakeland_terrier': 189,
#          'german_short-haired_pointer': 379,
#          'dragonfly': 673,
#          'sidewinder': 155,
#          'egyptian_cat': 471,
#          'indigo_bunting': 224,
#          'hognose_snake': 169,
#          'redbone': 228,
#          'orange': 300,
#          'holster': 391,
#          'komodo_dragon': 329,
#          'american_chameleon': 161,
#          'lemon': 222,
#          'isopod': 335,
#          'west_highland_white_terrier': 158,
#          'cornet': 560,
#          'hand-held_computer': 266,
#          'water_jug': 525,
#          'proboscis_monkey': 96,
#          'crock_pot': 548,
#          'digital_watch': 267,
#          'tibetan_terrier': 115,
#          'green_snake': 372,
#          'walker_hound': 180,
#          'soft-coated_wheaten_terrier': 188,
#          'sock': 207,
#          'jaguar': 85,
#          'ringneck_snake': 91,
#          'indri': 125,
#          'english_foxhound': 52,
#          'limpkin': 250,
#          'pomeranian': 40,
#          "jack-o'-lantern": 395,
#          'fly': 148,
#          'thunder_snake': 175,
#          'cardoon': 339,
#          'kit_fox': 106,
#          'cocker_spaniel': 138,
#          'mantis': 266,
#          'vizsla': 291,
#          'slide_rule': 309,
#          'wild_boar': 289,
#          'silky_terrier': 126,
#          'whiskey_jug': 46,
#          'guinea_pig': 480,
#          'yawl': 560,
#          'chickadee': 113,
#          'persian_cat': 111,
#          'siamese_cat': 317,
#          'kuvasz': 135,
#          'papillon': 56,
#          'irish_setter': 179,
#          'brabancon_griffon': 57,
#          'polecat': 185,
#          'toy_terrier': 174,
#          'eft': 187,
#          'collie': 60,
#          'norfolk_terrier': 57,
#          'old_english_sheepdog': 58,
#          'newfoundland': 227,
#          'lhasa': 74,
#          'bernese_mountain_dog': 116,
#          'monarch': 108,
#          'partridge': 246,
#          'king_snake': 72,
#          'tibetan_mastiff': 62,
#          'rock_beauty': 221,
#          'ringlet': 172,
#          'sealyham_terrier': 40,
#          'affenpinscher': 36,
#          'rock_python': 256,
#          'spaghetti_squash': 130,
#          'miniature_poodle': 196,
#          'reflex_camera': 271,
#          'malamute': 171,
#          'spotted_salamander': 62,
#          'border_terrier': 101,
#          'beagle': 200,
#          'junco': 170,
#          'otterhound': 23,
#          'keeshond': 22,
#          'green_mamba': 223,
#          'jacamar': 31,
#          'japanese_spaniel': 4,
#          'garden_spider': 25,
#          'black-and-tan_coonhound': 44,
#          'dandie_dinmont': 16})

# %%
classes_specified = ['pizza']#['acoustic_guitar']
background.filter_img_paths_by_class(mode='include', classes_specified=classes_specified)
# Out:
# Original: 1,803,460 -- Final: 2,507 -- Num Filtered: 1,800,953
# Finished setup.

# %% [markdown]
# ## Preview

# %%
bkg_img = background.sample()
plt.figure(figsize=(6,6))
plt.imshow(bkg_img)
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## Test

# %%
resnet18.eval()

bkg_img = background.sample()
bkg_img_pt = transformations(bkg_img).unsqueeze(dim=0).to(DEVICE)
with torch.no_grad():
    out_i = resnet18(bkg_img_pt)
predicted_label_i = modules.utils.get_prediction_idxs(out_i).cpu()
predicted_name_i = imagenet_idx2label[predicted_label_i[0]]

plt.figure(figsize=(6,6))
plt.imshow(bkg_img)
plt.title(f"Predicted Label: {predicted_name_i}")
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# # Dataset Handler

# %%
_OUTPUT_ROOT = 'render_output'
_BATCH_SIZE = 64

# %%
dataset_params = {
    "root"               : _OUTPUT_ROOT, 
    "background_handler" : background, 
    "background_active"  : True, 
    "mode_key"           : 'generate', # 'generate', 'demo'
    "transforms"         : transformations,
    "debug"              : True # True means background image only
}

dataset = modules.ShapeNet.Dataset(**dataset_params)
datahandler = DataLoader(dataset, batch_size=_BATCH_SIZE, shuffle=True)

# %% [markdown]
# ### Preview Images

# %%
for i, (imgs, class_ids, instance_ids) in enumerate(datahandler):
    break
grid_imgs = torchvision.utils.make_grid(imgs, normalize=True).permute(1,2,0)
plt.figure(figsize=(14,14))
plt.imshow(grid_imgs)
plt.axis('off')

# %% [markdown]
# # Evaluate

# %%
EVAL_BATCH_LIMIT = 10
BAD_MATCH_LABEL = -1

# %%
num_evaluated = 0
all_imgs = []
all_predictions = []
try:
    resnet18.eval()
    for i, (imgs, class_ids, instance_ids) in enumerate(datahandler):
        if i > EVAL_BATCH_LIMIT:
            break
        sys.stdout.write(f"\rEvaluating {i+1}/{len(datahandler)}...")
        sys.stdout.flush()

        # Setup labels
        shapenet_names = [shapenet_handler.lookup_name(class_id.item()) for class_id in class_ids]
        actual_labels = np.array([ele[1] for ele in shapenet_names])
        bad_idxs = np.array([i for i, ele in enumerate(actual_labels) if ele is None])
        if len(bad_idxs) > 0:
            actual_labels[bad_idxs] = BAD_MATCH_LABEL
        actual_labels = actual_labels.astype(np.int)
        
        # Send to device
        imgs = imgs.to(DEVICE)

        # Inference
        with torch.no_grad():
            output = resnet18(imgs)
        predicted_labels = modules.utils.get_prediction_idxs(output).cpu()
        predicted_names = [imagenet_idx2label[pred_idx] for pred_idx in predicted_labels]

        num_correct = (predicted_labels == torch.tensor(actual_labels)).sum()
        num_evaluated += predicted_labels.shape[0]

        if i == 0:
            all_imgs = imgs
            all_predicted_labels = predicted_names
        else:
            all_imgs = torch.cat([all_imgs, imgs], dim=0)
            all_predicted_labels += predicted_names
except KeyboardInterrupt:
    print("\nEnding Early")

# %%
accuracy = (num_correct / float(num_evaluated)).item()
print("accuracy: ", accuracy)

# %%
Counter(all_predicted_labels)

# %% [markdown]
# # Visualize

# %%
_VIS_LIMIT = 100
random_idxs = np.random.choice(range(all_imgs.shape[0]), _VIS_LIMIT, replace=False)
for i, idx in enumerate(random_idxs):
    img = all_imgs[idx]
    label = all_predicted_labels[idx]
    if i > _VIS_LIMIT:
        break
    img = (imagenet_xforms['denormalize'](img.clone()) * 255).byte()
    img_np = img.permute(1,2,0).cpu().numpy()
    annotated_im = modules.utils.add_labels_to_img(img_np, label, fontsize=1, x=0, y=50, text_color=[255,0,0])
    annotated_im = annotated_im[np.newaxis,...]
    if i == 0:
        all_annotated_images = annotated_im
    else:
        all_annotated_images = np.concatenate([all_annotated_images, annotated_im], axis=0)

# %%
all_annotated_images_pt = torch.tensor(all_annotated_images).permute(0,3,1,2)
all_annotated_grid = torchvision.utils.make_grid(all_annotated_images_pt, nrow=10).permute(1,2,0)

# %%
plt.figure(figsize=(14,14))
plt.imshow(all_annotated_grid)
plt.axis('off')
plt.savefig('Resnet18_examples.png', dpi=250)

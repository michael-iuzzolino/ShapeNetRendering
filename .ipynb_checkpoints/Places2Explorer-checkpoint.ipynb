# %%
import os
import glob
import numpy as np
import imageio
import cv2
import matplotlib.pyplot as plt
import torch
from torchvision.utils import make_grid

# %%
root = '/hdd/mliuzzolino/Places2/places365_standard/train'

# %%
out_filepath = 'places2_categories.txt'
with open(out_filepath, 'w') as outfile:
    for ele in glob.glob(f'{root}/*'):
        outfile.write(f"{os.path.basename(ele)}\n")

# %%
# !cat $out_filepath
# Out:
# computer_room
# slum
# water_park
# landfill
# river
# iceberg
# arena-performance
# catacomb
# escalator-indoor
# gas_station
# butte
# barndoor
# boathouse
# hospital_room
# amphitheater
# utility_room
# restaurant_kitchen
# vineyard
# cabin-outdoor
# playroom
# bazaar-indoor
# corn_field
# forest-broadleaf
# building_facade
# staircase
# physics_laboratory
# clothing_store
# bookstore
# hardware_store
# aquarium
# church-outdoor
# atrium-public
# lock_chamber
# orchestra_pit
# jail_cell
# arch
# diner-outdoor
# engine_room
# museum-indoor
# biology_laboratory
# highway
# bar
# aqueduct
# bus_interior
# phone_booth
# skyscraper
# moat-water
# hangar-indoor
# tower
# burial_chamber
# pasture
# balcony-interior
# berth
# picnic_area
# fire_station
# coast
# dorm_room
# mountain_path
# mezzanine
# ski_slope
# elevator_shaft
# boardwalk
# classroom
# rope_bridge
# airplane_cabin
# courtyard
# mansion
# assembly_line
# martial_arts_gym
# market-outdoor
# ball_pit
# pantry
# ...
